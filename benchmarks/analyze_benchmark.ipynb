# %% [markdown]
# # Benchmark Analysis
#
# Calculate mean absolute error and standard deviation for each model

# %%
import pandas as pd

# %%
df = pd.read_csv('benchmark-fixed.csv')
# Get columns that aren't metadata
model_cols = [col for col in df.columns if col not in ['dataset', 'sample_idx', 'label']]

# Calculate metrics for each model
metrics = []
for model in model_cols:
    diff_col = df[model] - df['label']
    metrics.append({
        'Model': model,
        'MAE': f"{diff_col.abs().mean():.2f}",
        'Error STD': f"{diff_col.std():.2f}"
    })

# Create and display metrics table
metrics_df = pd.DataFrame(metrics)
display(metrics_df)
# Out:
#                                   Model   MAE Error STD
# 0      meta-llama/Llama-3.2-3B-Instruct  1.78      3.32
# 1               meta-llama/Llama-3.2-3B  1.65      1.30
# 2     meta-llama/Llama-3.3-70B-Instruct   nan       nan
# 3                         Qwen/Qwen3-4B   nan       nan
# 4  Qwen/Qwen3-30B-A3B-Instruct-2507-FP8   nan       nan
# 5                  google/gemma-3-4b-it   nan       nan
# 6                  google/gemma-3-1b-it   nan       nan
# 7                  google/gemma-3-4b-pt   nan       nan
# 8                    openai/gpt-oss-20b   nan       nan
# 9      deepseek-ai/deepseek-llm-7b-chat   nan       nan

# %%
# Group by dataset and calculate statistics for each model
metrics = []

for dataset in df['dataset'].unique():
    dataset_df = df[df['dataset'] == dataset]
    for model in model_cols:
        diff_col = dataset_df[model] - dataset_df['label']
        metrics.append({
            'Model': model,
            'dataset': dataset,
            'MAE': f"{diff_col.abs().mean():.2f}",
            'Error STD': f"{diff_col.std():.2f}",
        })
        
all_metrics_df = pd.DataFrame(metrics)
display(all_metrics_df)
# Out:
#                                    Model       dataset   MAE Error STD
# 0       meta-llama/Llama-3.2-3B-Instruct  data_trivial  1.46      1.83
# 1                meta-llama/Llama-3.2-3B  data_trivial  1.46      1.22
# 2      meta-llama/Llama-3.3-70B-Instruct  data_trivial   nan       nan
# 3                          Qwen/Qwen3-4B  data_trivial   nan       nan
# 4   Qwen/Qwen3-30B-A3B-Instruct-2507-FP8  data_trivial   nan       nan
# 5                   google/gemma-3-4b-it  data_trivial   nan       nan
# 6                   google/gemma-3-1b-it  data_trivial   nan       nan
# 7                   google/gemma-3-4b-pt  data_trivial   nan       nan
# 8                     openai/gpt-oss-20b  data_trivial   nan       nan
# 9       deepseek-ai/deepseek-llm-7b-chat  data_trivial   nan       nan
# 10      meta-llama/Llama-3.2-3B-Instruct     data_easy  1.27      1.63
# 11               meta-llama/Llama-3.2-3B     data_easy  1.63      1.43
# 12     meta-llama/Llama-3.3-70B-Instruct     data_easy   nan       nan
# 13                         Qwen/Qwen3-4B     data_easy   nan       nan
# 14  Qwen/Qwen3-30B-A3B-Instruct-2507-FP8     data_easy   nan       nan
# 15                  google/gemma-3-4b-it     data_easy   nan       nan
# 16                  google/gemma-3-1b-it     data_easy   nan       nan
# 17                  google/gemma-3-4b-pt     data_easy   nan       nan
# 18                    openai/gpt-oss-20b     data_easy   nan       nan
# 19      deepseek-ai/deepseek-llm-7b-chat     data_easy   nan       nan
# 20      meta-llama/Llama-3.2-3B-Instruct   data_medium  2.14      4.33
# 21               meta-llama/Llama-3.2-3B   data_medium  1.73      1.27
# 22     meta-llama/Llama-3.3-70B-Instruct   data_medium   nan       nan
# 23                         Qwen/Qwen3-4B   data_medium   nan       nan
# 24  Qwen/Qwen3-30B-A3B-Instruct-2507-FP8   data_medium   nan       nan
# 25                  google/gemma-3-4b-it   data_medium   nan       nan
# 26                  google/gemma-3-1b-it   data_medium   nan       nan
# 27                  google/gemma-3-4b-pt   data_medium   nan       nan
# 28                    openai/gpt-oss-20b   data_medium   nan       nan
# 29      deepseek-ai/deepseek-llm-7b-chat   data_medium   nan       nan
# 30      meta-llama/Llama-3.2-3B-Instruct     data_hard  2.24      4.34
# 31               meta-llama/Llama-3.2-3B     data_hard  1.76      1.25
# 32     meta-llama/Llama-3.3-70B-Instruct     data_hard   nan       nan
# 33                         Qwen/Qwen3-4B     data_hard   nan       nan
# 34  Qwen/Qwen3-30B-A3B-Instruct-2507-FP8     data_hard   nan       nan
# 35                  google/gemma-3-4b-it     data_hard   nan       nan
# 36                  google/gemma-3-1b-it     data_hard   nan       nan
# 37                  google/gemma-3-4b-pt     data_hard   nan       nan
# 38                    openai/gpt-oss-20b     data_hard   nan       nan
# 39      deepseek-ai/deepseek-llm-7b-chat     data_hard   nan       nan

# %%
# Calculate metrics for each dataset type
dataset_metrics = []
for dataset in df['dataset'].unique():
    dataset_df = df[df['dataset'] == dataset]
    diff_cols = dataset_df[model_cols].subtract(dataset_df['label'], axis=0)
    dataset_metrics.append({
        'Dataset': dataset,
        'MAE': f"{diff_cols.abs().mean().mean():.2f}", 
        'Error STD': f"{diff_cols.std().mean():.2f}"
    })

# Create and display metrics table
dataset_metrics_df = pd.DataFrame(dataset_metrics)
display(dataset_metrics_df)
# Out:
#         Dataset   MAE Error STD
# 0  data_trivial  1.46      1.52
# 1     data_easy  1.45      1.53
# 2   data_medium  1.94      2.80
# 3     data_hard  2.00      2.80

# %% [markdown]
# Generate markdown

# %%
with open('METRICS.md', 'w') as f:
    f.write(metrics_df.to_markdown(index=False) + '\n\n')
    f.write(all_metrics_df.to_markdown(index=False) + '\n\n')
    f.write(dataset_metrics_df.to_markdown(index=False) + '\n\n')

# %% [markdown]
# Fix bug where dataset names didn't get properly initialized

# %%
# df = pd.read_csv('benchmark-meta-llama-Llama-3.2-3B.csv')
# dataset_names = ['data_trivial', 'data_easy', 'data_medium', 'data_hard']
# df['dataset'] = [dataset_names[i // 5000] for i in range(len(df))]
# df.to_csv('benchmark-fixed.csv', index=False)
